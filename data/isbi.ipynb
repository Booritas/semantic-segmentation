# %%
from dataset import Dataset
from PIL import Image, ImageSequence
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from isbi import ISBI_2012
# Out:
# Using TensorFlow backend.

# %%
dataset = ISBI_2012()
generator = dataset.generator('training', batch_size=20)

# %%
image_batch, label_batch = next(generator)
image_batch.shape, label_batch.shape
# Out:
# ((20, 512, 512, 1), (20, 512, 512, 1))

# %%
from matplotlib import pyplot

# %%
index = 10
image = image_batch[index,:,:,0]
label = label_batch[index,:,:,0]
/

# %%
pyplot.imshow(label,cmap='gray')
